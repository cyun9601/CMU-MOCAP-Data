# %%
import pickle
from utils_ccy.skeleton.visualization import draw, unnormalize, animation, pkl_draw

joint_names = ['root', 'lhipjoint', 'lfemur', 'ltibia', 'lfoot', 'ltoes', 'rhipjoint', 
               'rfemur', 'rtibia', 'rfoot', 'rtoes', 'lowerback', 'upperback', 'thorax', 
               'lowerneck', 'upperneck', 'head', 'lclavicle', 'lhumerus', 'lradius', 'lwrist', 
               'lhand', 'lfingers', 'lthumb', 'rclavicle', 'rhumerus', 'rradius', 'rwrist', 'rhand', 'rfingers', 'rthumb']

# Kinematic structure. 밖에서 안쪽 방향으로
paris = {
    'CMU/asfamc': [
        (1, 12), (2, 1), (3, 2), (4, 3), (5, 4),
        (6, 5), (7, 1), (8, 7), (9, 8), (10, 9),
        (11, 10), (12, 13), (13, 14), (14, 15), (15, 15),
        (16, 15), (17, 16), (18, 15), (19, 18), (20, 19),
        (21, 20), (22, 21), (23, 22), (24, 21), (25, 15),
        (26, 25), (27, 26), (28, 27), (29, 28), (30, 29), (31, 28)
    ],
    'CMU/asfamc_21joints': [
        (1, 10), (2, 1), (3, 2), (4, 3), (5, 4),
        (6, 1), (7, 6), (8, 7), (9, 8), (10, 11),
        (11, 12), (12, 12), (13, 12), (14, 12), (15, 14),
        (16, 15), (17, 16), (18, 12), (19, 18), (20, 19),
        (21, 20)
    ]
}

# %%
with open('./processed_data/CMU/asfamc/full_joint.pkl', 'rb') as f : 
    full_data, pose_mean, pose_max = pickle.load(f).values()
    full_data = unnormalize(full_data, pose_mean, pose_max)

# %%
T = 0
draw(full_data[0:3, :, T, :, 0], paris=paris['CMU/asfamc_21joints'], blank_position=None, figsize=(10, 10), elev=0, azim=0, yz_rotation=True, title=None, font_size=10, axis_off = False)
# Out:
# /mnt/disk1/changyun/Exo_Suit/CMU Data Parsing/utils_ccy/skeleton/visualization.py:90: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot('1' + str(N) + str(i+1), projection='3d')
# /mnt/disk1/changyun/Exo_Suit/CMU Data Parsing/utils_ccy/skeleton/visualization.py:90: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot('1' + str(N) + str(i+1), projection='3d')
# /mnt/disk1/changyun/Exo_Suit/CMU Data Parsing/utils_ccy/skeleton/visualization.py:90: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot('1' + str(N) + str(i+1), projection='3d')

# %%
animation(full_data[10], paris['CMU/asfamc_21joints'], figsize=(5, 5), elev = -90, azim = 90, axis_off=False)

# %%
pkl_draw('./processed_data/CMU/asfamc/full_joint.pkl', 
         data_index=0, 
         sequence=[0, 10], 
         paris=paris['CMU/asfamc_21joints'], 
         unnorm=True, yz_rotation=True, elev=None, azim=None)
# Out:
# /mnt/disk1/changyun/Exo_Suit/CMU Data Parsing/utils_ccy/skeleton/visualization.py:90: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot('1' + str(N) + str(i+1), projection='3d')
# /mnt/disk1/changyun/Exo_Suit/CMU Data Parsing/utils_ccy/skeleton/visualization.py:90: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = fig.add_subplot('1' + str(N) + str(i+1), projection='3d')
